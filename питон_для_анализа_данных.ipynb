# %% [markdown]
# <a href="https://colab.research.google.com/github/b028888/firts_project/blob/master/%D0%BF%D0%B8%D1%82%D0%BE%D0%BD_%D0%B4%D0%BB%D1%8F_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Привет, мир!")
# Out:
# Привет, мир!

# %%
newlist = [1, 2, 3]
print(newlist)

newlist[0] = 10
print(newlist)
newlist[1] = 20
print(newlist)
newlist[2] = 30
print(newlist)
# Out:
# [1, 2, 3]
# [10, 2, 3]
# [10, 20, 3]
# [10, 20, 30]
